# %% [markdown]
# ## Using Python's NumPy and Pandas for data analysis
#
# The **[Pandas](https://pandas.pydata.org/)** module allows the easy analysis of data sets (organized in rows like in a spreadsheet) through a high-level data frame structure.
#
# Pandas requires **[NumPy](http://www.numpy.org/)**, which allows the creation of a low-level data structure like multidemensional arrays.
#
# That is why everytime you need Pandas, you need to import the pandas and numby libraries as shown:

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# <hr>
#
# ## Let's learn through examples
#
# ### 1) Creating a dataframe in the code
#
# We can use the .DataFrame to explicitly add any data we want directly into the code as shown:

# %%
# You can create your own data right in the code using DataFrame(). 
df = pd.DataFrame(
    [
        ['twtrid1','1:25 PM - 28 Nov 2018','text 1',0,3,2],
        ['twtrid2','3:00 PM - 26 Nov 2018','text 2',1,12,14],
        ['twtrid3','7:14 PM - 8 Nov 2018','text 3',4,12,17],
        ['twtrid4','10:33 AM - 12 Nov 2018','text 4',0,3,2],
        ['twtrid5','8:55 AM - 30 Nov 2018','text 5',6,10,6]
    ],

#You can use index gives each row a specific number like an excel sheet
    index = [1,2,3,4,5],

#You can give the columns names as well using the 'columns' variable
    columns = ['tweeter','time','text','replies','retweets','favorites'])

df
# Out:
#    tweeter                    time    text  replies  retweets  favorites
# 1  twtrid1   1:25 PM - 28 Nov 2018  text 1        0         3          2
# 2  twtrid2   3:00 PM - 26 Nov 2018  text 2        1        12         14
# 3  twtrid3    7:14 PM - 8 Nov 2018  text 3        4        12         17
# 4  twtrid4  10:33 AM - 12 Nov 2018  text 4        0         3          2
# 5  twtrid5   8:55 AM - 30 Nov 2018  text 5        6        10          6

# %% [markdown]
# <hr>
#
# ### 2) Importing data from an external file
#
# #### We can also read data from an external source such as a file using read_csv()

# %%
filename = 'data/tweet_data.csv'
df = pd.read_csv(filename)
df.head() #We use head() as it will display only the first 5 records (for easier viewing)
# Out:
#      tweeter_id                                         avatar_url  \
# 0   GSTICseries  https://pbs.twimg.com/profile_images/875623570...
# 1      11ionArt  https://pbs.twimg.com/profile_images/106785384...
# 2   G2H2_Geneva  https://pbs.twimg.com/profile_images/778233965...
# 3  AnnaRHaskins  https://pbs.twimg.com/profile_images/941757829...
# 4     PensiveTM  https://pbs.twimg.com/profile_images/104786562...
#
#                   tw_time                                            tw_text  \
# 0   1:25 PM - 28 Nov 2018  All fueled up? Afternoon session (Waste)#Water...
# 1  11:20 AM - 28 Nov 2018  DID YOU KNOW? 5 Ongoing Trends that Will Resha...
# 2   6:08 AM - 28 Nov 2018  Global health disruptors: Millennium developme...
# 3   1:35 AM - 28 Nov 2018  In class today I referenced the Millennium Dev...
# 4   6:08 PM - 27 Nov 2018  The true extent of global poverty and hunger: ...
#
#    tw_replies  tw_retweets  tw_favorites
# 0           0            1             2
# 1           0            1             0
# 2           1            2             6
# 3           3            2            92
# 4           0            1             1

# %% [markdown]
# ### 3) Get information about the data set (types, index, columns, values)
# #### By calling .dtypes, .index, .columns, .values you can return information about your data set as shown below.

# %%
#show data types 
df.dtypes
# Out:
# tweeter_id      object
# avatar_url      object
# tw_time         object
# tw_text         object
# tw_replies       int64
# tw_retweets      int64
# tw_favorites     int64
# dtype: object

# %%
#show index
df.index
# Out:
# RangeIndex(start=0, stop=135, step=1)

# %%
#show columns
df.columns
# Out:
# Index(['tweeter_id', 'avatar_url', 'tw_time', 'tw_text', 'tw_replies',
#        'tw_retweets', 'tw_favorites'],
#       dtype='object')

# %%
#### You can also get the actual values of a specific row by calling it by its index as shown

# %%
#show values of the first item
df.values[0]
# Out:
# array(['GSTICseries',
#        'https://pbs.twimg.com/profile_images/875623570436575233/tndS3CqJ_bigger.jpg',
#        '1:25 PM - 28 Nov 2018',
#        'All fueled up? Afternoon session (Waste)#Water as a resource. Special focus on SDG 6. Purpose: review progress of water coming towards #SDGs, reflecting on millennium development goals, and what is the role of science, technology and innovation in reaching these goals. #GSTICpic.twitter.com/vXeKzTUBsG',
#        0, 1, 2], dtype=object)

# %% [markdown]
# ### 4) Specific columns to use
# #### You can easily specify which values of the data frame that you wish to use and ignore the rest as shown:

# %%
#Let's say we only want to see the texts and number of retweets only, then we can specify them as shown
df1 = df[['tw_text','tw_retweets']]
df1.head()
# Out:
#                                              tw_text  tw_retweets
# 0  All fueled up? Afternoon session (Waste)#Water...            1
# 1  DID YOU KNOW? 5 Ongoing Trends that Will Resha...            1
# 2  Global health disruptors: Millennium developme...            2
# 3  In class today I referenced the Millennium Dev...            2
# 4  The true extent of global poverty and hunger: ...            1

# %% [markdown]
# ### 5) Sorting rows
# #### You can also sort the data by any of the variable values (e.g., retweets) using the .sort function as shown:

# %%
#specify the second parameter to indicate that it will be in descending order (most retweeted first). Notice that the index now is scrambled since the sorting changed from the original setup
df1.sort_values('tw_retweets', ascending=False).head()
# Out:
#                                                tw_text  tw_retweets
# 65   What is Millennium Development Goals and what ...           42
# 45   "SHEER WILLPOWER! We were the ONLY Sub-Saharan...           34
# 30   How well can you pronounce "Millennium Develop...           28
# 105  Did the world actually achieve the Millennium ...           28
# 108  Sustainable Development Goals:\n\nStarted 2015...           11

# %%
#If you want to fix the index, you can do a reset and drop the old index using .reset_index(drop=True)
df_reindexed=df1.sort_values('tw_retweets', ascending=False).reset_index(drop=True)
df_reindexed.head()
# Out:
#                                              tw_text  tw_retweets
# 0  What is Millennium Development Goals and what ...           42
# 1  "SHEER WILLPOWER! We were the ONLY Sub-Saharan...           34
# 2  How well can you pronounce "Millennium Develop...           28
# 3  Did the world actually achieve the Millennium ...           28
# 4  Sustainable Development Goals:\n\nStarted 2015...           11

# %% [markdown]
# ### 6) Sorting by multiple columns:
# #### To do that, you can specify the column names and whether sorting will be ascending or descending for each have the same number of

# %%
#Sort by retweets and then by the text messages (ascending in alphabetical order)
df2=df1.sort_values(by=['tw_retweets','tw_text'], ascending=[False,True]).reset_index(drop=True)
df2.head()
# Out:
#                                              tw_text  tw_retweets
# 0  What is Millennium Development Goals and what ...           42
# 1  "SHEER WILLPOWER! We were the ONLY Sub-Saharan...           34
# 2  Did the world actually achieve the Millennium ...           28
# 3  How well can you pronounce "Millennium Develop...           28
# 4  "There is a huge different between sustainable...           11

# %% [markdown]
# ### 7) Selecting a subset of a data frame
# #### You can also specify that you wish to extract only the top or lower rows for example. This can be done using the ***.head(), .tail() and brackets [a:b] *** functions as shown:

# %%
#Print the top 10 tweets in terms of retweets (sorted alphabetically)
df2.head(10)
# Out:
#                                              tw_text  tw_retweets
# 0  What is Millennium Development Goals and what ...           42
# 1  "SHEER WILLPOWER! We were the ONLY Sub-Saharan...           34
# 2  Did the world actually achieve the Millennium ...           28
# 3  How well can you pronounce "Millennium Develop...           28
# 4  "There is a huge different between sustainable...           11
# 5  Sustainable Development Goals:\n\nStarted 2015...           11
# 6  Atiku campaigns told Nigeria is developmental ...           10
# 7  A1. SDGs are goals formulated to build on the ...            9
# 8  GLOBAL FRAMEWORKS IN OPERATION:\n\nMillennium ...            9
# 9  The 17 Sustainable development goals build on ...            9

# %%
#Alternatively, you can always use df2[:10] to achieve the same result:
df2[:10]
# Out:
#                                              tw_text  tw_retweets
# 0  What is Millennium Development Goals and what ...           42
# 1  "SHEER WILLPOWER! We were the ONLY Sub-Saharan...           34
# 2  Did the world actually achieve the Millennium ...           28
# 3  How well can you pronounce "Millennium Develop...           28
# 4  "There is a huge different between sustainable...           11
# 5  Sustainable Development Goals:\n\nStarted 2015...           11
# 6  Atiku campaigns told Nigeria is developmental ...           10
# 7  A1. SDGs are goals formulated to build on the ...            9
# 8  GLOBAL FRAMEWORKS IN OPERATION:\n\nMillennium ...            9
# 9  The 17 Sustainable development goals build on ...            9

# %%
#Print the last 5 tweets in terms of retweets (sorted alphabetically)
df2.tail(5)
# Out:
#                                                tw_text  tw_retweets
# 130  Who are the ignorant youths who worked with @a...            0
# 131  atiku IS OUTDATED and his PLAN is too! How can...            0
# 132  “It is aimed at transforming the amnesty benef...            0
# 133  “The Philippines then could not pass the mille...            0
# 134  “The un’s Millennium Development Goals include...            0

# %%
#Similarly, you can always use df2[-5:] (using '-' denotes starting from the end) to achieve the same result:
df2[-5:]
# Out:
#                                                tw_text  tw_retweets
# 130  Who are the ignorant youths who worked with @a...            0
# 131  atiku IS OUTDATED and his PLAN is too! How can...            0
# 132  “It is aimed at transforming the amnesty benef...            0
# 133  “The Philippines then could not pass the mille...            0
# 134  “The un’s Millennium Development Goals include...            0

# %%
#Print the rows from 10 to 18:
df2[10:19] #notice how the second parameter is not included in the final output
# Out:
#                                               tw_text  tw_retweets
# 10  .@MinisterRw_Edu :One of the key strategic pri...            8
# 11  "SHEER WILLPOWER!\nWe were the ONLY Sub-Sahara...            7
# 12  Hello Mr Abubakar ,i know you are tired of my ...            7
# 13  Millennium Development Goals ended in 2015\n\n...            7
# 14  The 17 Sustainable development goals build on ...            7
# 15  Good morning beautiful people. The rest of you...            6
# 16  Kenya started action on Millennium Development...            5
# 17  A2. We might also say its an extension of the ...            4
# 18  Cuba is one of the most successful countries i...            4

# %% [markdown]
# ### 8) Getting max, min, sum and mean values
# #### There are specific functions that pandas has to get the above values easily as shown:

# %%
#Print the tweet that has the maximum number of retweets
df['tw_retweets'].max()
# Out:
# 42

# %%
#Print the tweet that has the minimum number of retweets
df['tw_retweets'].min()
# Out:
# 0

# %%
#Print the tweet that has the mean value of retweets
df['tw_retweets'].mean()
# Out:
# 2.3407407407407406

# %%
#You can also round off the number using the round() function
round(df['tw_retweets'].mean())
# Out:
# 2

# %%
#Sometimes, it is useful to use the median, e.g., when there is an outlier. This can be done as follows:
df2[:10].median()[0] #We use [0] because the result is a list of two arrays as per documentation.
# Out:
# 11.0

# %% [markdown]
# ### 9) Descriptive statistics
# #### When you need some basic statistical information about numeric columns in your dataset, use describe() as shown:

# %%
df.describe()
# Out:
#        tw_replies  tw_retweets  tw_favorites
# count  135.000000   135.000000    135.000000
# mean     0.414815     2.340741      4.059259
# std      1.373443     6.017590     11.285814
# min      0.000000     0.000000      0.000000
# 25%      0.000000     0.000000      0.000000
# 50%      0.000000     0.000000      0.000000
# 75%      0.000000     2.000000      3.000000
# max     14.000000    42.000000     92.000000

# %% [markdown]
# ### 10) Find unique values
# #### You sometimes only want to know the unique values that exist in a column. To do so, use unique() as shown:

# %%
#Find the number and values of unique Twitter usernames in the full dataset
unique_tweeters=df['tweeter_id'].unique()
print("There are "+str(len(unique_tweeters))+" unique users as shown below:")
for i in range(len(unique_tweeters)):
    print(i," ",unique_tweeters[i])
# Out:
# There are 114 unique users as shown below:
# 0   GSTICseries
# 1   11ionArt
# 2   G2H2_Geneva
# 3   AnnaRHaskins
# 4   PensiveTM
# 5   drcamarin
# 6   AlanBenstock
# 7   globalpeacef1
# 8   egumboslav
# 9   MalariaPapers
# 10   CheltColGeog
# 11   60Macc
# 12   kiplangatLedama
# 13   faziarizvi
# 14   Tarif_Naqsh
# 15   IfeanyiUddin
# 16   HallidayInc
# 17   Gbolarin_
# 18   Rwanda_Edu
# 19   larrykipz
# 20   tjfas
# 21   chris_m_h
# 22   DJStrumfels
# 23   justadded
# 24   RoyalKenyah
# 25   Dmarigiri_
# 26   teddyeugene
# 27   kunleMyk
# 28   AdesugbaDipo
# 29   radiokimilili
# 30   ChefKeidi
# 31   nicktubechannel
# 32   MadiSharma1
# 33   TheMacAnon
# 34   GodoStoyke
# 35   Asamoh_
# 36   ForeverEritrea
# 37   RaimeMarina
# 38   mfascinari
# 39   Future_Cities
# 40   MakaraNuel
# 41   Underground_RT
# 42   ClimateWed
# 43   Qwame_Dankwah
# 44   adex0057
# 45   BankWindhoek
# 46   MSTCDC
# 47   WORBLO
# 48   Ody_johnson
# 49   USF_Economics
# 50   Karovoni
# 51   thebardogbamola
# 52   MouriceAgumba
# 53   WaleMicaiah
# 54   SaleemAmusa
# 55   UgochiJaneTrump
# 56   realjohnafolabi
# 57   onayinka_segun
# 58   purple_billion
# 59   osayamwenoghosa
# 60   woye1
# 61   drdebodun
# 62   ayo_david
# 63   daylalalal
# 64   kbremote
# 65   DrIkramulHaq
# 66   Valdemort18
# 67   suleimanhuzzein
# 68   BrookingsGlobal
# 69   DukeDCID
# 70   umichsphglobal
# 71   techie_2000
# 72   PPAFofficial
# 73   sharanjit
# 74   zeropovertyPH
# 75   tumaini_tz
# 76   HipHopTalker
# 77   ChildrenUg
# 78   GW_isp
# 79   gbemy01
# 80   paulwebs1
# 81   GlenTarman
# 82   Change_Maldives
# 83   princesscuria
# 84   NigerDeltaRpts
# 85   NofNewsFilipino
# 86   GCICUganda
# 87   jackielidubwi
# 88   MrsKohlrabi
# 89   MaxCRoser
# 90   SDGsNGA
# 91   wbcbray
# 92   StatiSense
# 93   iameneji
# 94   Kempez2017
# 95   Opsy_damen
# 96   ziliyax
# 97   design_atelier
# 98   NUFC_OurClub
# 99   amutunga2011
# 100   Miryam1968
# 101   BethuTongai
# 102   LeviKabwato
# 103   MSirani
# 104   JellyfishJesus
# 105   UnitedWayDE
# 106   msmarbella
# 107   silverkingg
# 108   YamatLucas
# 109   odoidaniel1
# 110   iamkayfactor
# 111   atabinore
# 112   rosariso2016
# 113   ciryan_nelson

# %% [markdown]
# ### 11) Group by (equivalent of pivot tables in MS Excel)
# #### When you wish to group variables based on a particular value to do other calculations such as find the count, sum, etc., then pandas offers a handy function called groupby(), which can be used as shown:

# %%
#Get the total number of tweets that were sent by each user:
df.groupby(['tweeter_id']).agg({'tw_text': ['count']})
# Out:
#                 tw_text
#                   count
# tweeter_id
# 11ionArt              1
# 60Macc                1
# AdesugbaDipo          1
# AlanBenstock          1
# AnnaRHaskins          1
# Asamoh_               1
# BankWindhoek          1
# BethuTongai           1
# BrookingsGlobal       2
# Change_Maldives       1
# ChefKeidi             1
# CheltColGeog          1
# ChildrenUg            2
# ClimateWed            3
# DJStrumfels           2
# Dmarigiri_            1
# DrIkramulHaq          1
# DukeDCID              1
# ForeverEritrea        1
# Future_Cities         1
# G2H2_Geneva           1
# GCICUganda            1
# GSTICseries           1
# GW_isp                1
# Gbolarin_             1
# GlenTarman            1
# GodoStoyke            1
# HallidayInc           1
# HipHopTalker          1
# IfeanyiUddin          1
# ...                 ...
# justadded             1
# kbremote              1
# kiplangatLedama       1
# kunleMyk              1
# larrykipz             1
# mfascinari            1
# msmarbella            1
# nicktubechannel       1
# odoidaniel1           1
# onayinka_segun        1
# osayamwenoghosa       1
# paulwebs1             1
# princesscuria         1
# purple_billion        1
# radiokimilili         1
# realjohnafolabi       1
# rosariso2016          1
# sharanjit             1
# silverkingg           1
# suleimanhuzzein       1
# techie_2000           1
# teddyeugene           2
# thebardogbamola       1
# tjfas                 1
# tumaini_tz            1
# umichsphglobal        1
# wbcbray               1
# woye1                 1
# zeropovertyPH         1
# ziliyax               1
#
# [114 rows x 1 columns]

# %%
#You can also do the same using sum, for example to sum up the total number of retweets for each user:
df.groupby(['tweeter_id']).agg({'tw_retweets': ['sum']})
# Out:
#                 tw_retweets
#                         sum
# tweeter_id
# 11ionArt                  1
# 60Macc                    0
# AdesugbaDipo              1
# AlanBenstock              0
# AnnaRHaskins              2
# Asamoh_                   1
# BankWindhoek              0
# BethuTongai               0
# BrookingsGlobal           3
# Change_Maldives           0
# ChefKeidi                 0
# CheltColGeog              0
# ChildrenUg                0
# ClimateWed                4
# DJStrumfels               0
# Dmarigiri_                5
# DrIkramulHaq              1
# DukeDCID                  1
# ForeverEritrea            7
# Future_Cities             0
# G2H2_Geneva               2
# GCICUganda                2
# GSTICseries               1
# GW_isp                    0
# Gbolarin_                 2
# GlenTarman                0
# GodoStoyke                0
# HallidayInc               0
# HipHopTalker              0
# IfeanyiUddin              0
# ...                     ...
# justadded                 0
# kbremote                  0
# kiplangatLedama           0
# kunleMyk                 28
# larrykipz                 2
# mfascinari                0
# msmarbella                0
# nicktubechannel           1
# odoidaniel1               4
# onayinka_segun            0
# osayamwenoghosa           0
# paulwebs1                 2
# princesscuria             0
# purple_billion            0
# radiokimilili             1
# realjohnafolabi           0
# rosariso2016              4
# sharanjit                 0
# silverkingg               0
# suleimanhuzzein           0
# techie_2000               0
# teddyeugene               8
# thebardogbamola           1
# tjfas                     0
# tumaini_tz                0
# umichsphglobal            0
# wbcbray                   0
# woye1                    42
# zeropovertyPH             0
# ziliyax                   0
#
# [114 rows x 1 columns]

# %%
#If you have multiple values to aggregate with, you can simply add them to the agg() function as shown:
df.groupby(['tweeter_id']).agg({'tw_text':['count'],'tw_retweets': ['sum'],'tw_replies':['sum'],'tw_favorites':['sum']})
# Out:
#                 tw_text tw_retweets tw_replies tw_favorites
#                   count         sum        sum          sum
# tweeter_id
# 11ionArt              1           1          0            0
# 60Macc                1           0          0            0
# AdesugbaDipo          1           1          0            0
# AlanBenstock          1           0          0            0
# AnnaRHaskins          1           2          3           92
# Asamoh_               1           1          1            2
# BankWindhoek          1           0          0            1
# BethuTongai           1           0          1            0
# BrookingsGlobal       2           3          0            3
# Change_Maldives       1           0          1            0
# ChefKeidi             1           0          0            0
# CheltColGeog          1           0          0            0
# ChildrenUg            2           0          0            0
# ClimateWed            3           4          0            2
# DJStrumfels           2           0          0            0
# Dmarigiri_            1           5          0            5
# DrIkramulHaq          1           1          0            1
# DukeDCID              1           1          0            4
# ForeverEritrea        1           7          1           13
# Future_Cities         1           0          0            0
# G2H2_Geneva           1           2          1            6
# GCICUganda            1           2          1            1
# GSTICseries           1           1          0            2
# GW_isp                1           0          0            0
# Gbolarin_             1           2          1            0
# GlenTarman            1           0          0            1
# GodoStoyke            1           0          0            3
# HallidayInc           1           0          0            0
# HipHopTalker          1           0          0            2
# IfeanyiUddin          1           0          0            0
# ...                 ...         ...        ...          ...
# justadded             1           0          0            0
# kbremote              1           0          0            0
# kiplangatLedama       1           0          0            5
# kunleMyk              1          28         14            5
# larrykipz             1           2          0            0
# mfascinari            1           0          0            0
# msmarbella            1           0          1            0
# nicktubechannel       1           1          1            3
# odoidaniel1           1           4          0            7
# onayinka_segun        1           0          0            0
# osayamwenoghosa       1           0          0            0
# paulwebs1             1           2          0            2
# princesscuria         1           0          0            0
# purple_billion        1           0          0            0
# radiokimilili         1           1          0            1
# realjohnafolabi       1           0          0            0
# rosariso2016          1           4          0            5
# sharanjit             1           0          0            0
# silverkingg           1           0          0            1
# suleimanhuzzein       1           0          0            0
# techie_2000           1           0          0            0
# teddyeugene           2           8          0            6
# thebardogbamola       1           1          0            3
# tjfas                 1           0          1            0
# tumaini_tz            1           0          0            2
# umichsphglobal        1           0          0            0
# wbcbray               1           0          0            0
# woye1                 1          42          5           56
# zeropovertyPH         1           0          0            0
# ziliyax               1           0          0            0
#
# [114 rows x 4 columns]

# %% [markdown]
# ### 11) Sort a groupped data frame
# #### Once a grouped data frame is produced, you can run it through the sort function explained earlier as shown:

# %%
#This is more complex as it requires passing a custom function to apply and then sorting the values.
def my_agg(x):
    names = { #create a new pandas series based on the aggregated data below
        'Tweets': x['tw_text'].count(), #count the number of tweets and name the column 'Tweets'
        'Replies':  x['tw_replies'].sum(), #add up the number of replies and name the column 'Replies'
        'Retweets': x['tw_retweets'].sum(), #add up the number of retweets and name the column 'Retweets'
        'Favorites': x['tw_favorites'].sum()} #add up the number of favorites and name the column 'Favorites'
    return pd.Series(names, index=['Tweets', 'Replies', 'Retweets','Favorites']) #ensure that the index is updated

grouped_df=df.groupby('tweeter_id').apply(my_agg)

#Let's see if the group is properly created and structured
grouped_df.head()
# Out:
#               Tweets  Replies  Retweets  Favorites
# tweeter_id
# 11ionArt           1        0         1          0
# 60Macc             1        0         0          0
# AdesugbaDipo       1        0         1          0
# AlanBenstock       1        0         0          0
# AnnaRHaskins       1        3         2         92

# %%
#The next step is simply to sort the newly generated data frame as shown earlier
#Here, we sort in descending order by the number of favorites, then tweets, replies and retweets

grouped_df.sort_values(by=['Favorites','Tweets','Replies','Retweets'], ascending=[False,False,False,False])
# Out:
#                  Tweets  Replies  Retweets  Favorites
# tweeter_id
# AnnaRHaskins          1        3         2         92
# woye1                 1        5        42         56
# Underground_RT        1        0        34         54
# MaxCRoser             1        2        28         36
# iameneji              1        2         6         35
# atabinore             1        0         9         18
# adex0057              1        0        10         17
# SDGsNGA               2        3        13         14
# ForeverEritrea        1        1         7         13
# MSTCDC                1        0        11         13
# MadiSharma1           1        0         2         13
# amutunga2011          1        0         4         10
# ayo_david             1        0         3         10
# RoyalKenyah           1        1         9          9
# Ody_johnson           2        1         8          8
# WaleMicaiah           1        1         7          8
# chris_m_h             1        1         4          8
# Rwanda_Edu            1        2         8          7
# StatiSense            1        0         9          7
# odoidaniel1           1        0         4          7
# teddyeugene           2        0         8          6
# G2H2_Geneva           1        1         2          6
# kunleMyk              1       14        28          5
# Qwame_Dankwah         1        1         4          5
# Dmarigiri_            1        0         5          5
# iamkayfactor          1        0         4          5
# rosariso2016          1        0         4          5
# kiplangatLedama       1        0         0          5
# UgochiJaneTrump       1        1         3          4
# Karovoni              1        0         4          4
# ...                 ...      ...       ...        ...
# Future_Cities         1        0         0          0
# GW_isp                1        0         0          0
# HallidayInc           1        0         0          0
# IfeanyiUddin          1        0         0          0
# MSirani               1        0         0          0
# MakaraNuel            1        0         0          0
# MalariaPapers         1        0         0          0
# MouriceAgumba         1        0         0          0
# NUFC_OurClub          1        0         0          0
# NofNewsFilipino       1        0         0          0
# Opsy_damen            1        0         0          0
# RaimeMarina           1        0         0          0
# Tarif_Naqsh           1        0         0          0
# Valdemort18           1        0         0          0
# WORBLO                1        0         0          0
# justadded             1        0         0          0
# kbremote              1        0         0          0
# mfascinari            1        0         0          0
# onayinka_segun        1        0         0          0
# osayamwenoghosa       1        0         0          0
# princesscuria         1        0         0          0
# purple_billion        1        0         0          0
# realjohnafolabi       1        0         0          0
# sharanjit             1        0         0          0
# suleimanhuzzein       1        0         0          0
# techie_2000           1        0         0          0
# umichsphglobal        1        0         0          0
# wbcbray               1        0         0          0
# zeropovertyPH         1        0         0          0
# ziliyax               1        0         0          0
#
# [114 rows x 4 columns]

# %% [markdown]
# ### 12) Filtering data in a dataset
# #### Occasionally, you would like to only select rows that meet a particular condition (similar to the MS Excel filter method)
# #### This is easily done in pandas using the query() method as shown:

# %%
#Filter out all those tweets that do not have any replies and show the rest
df.query('tw_replies > 0').reset_index(drop=True)
# Out:
#          tweeter_id                                         avatar_url  \
# 0       G2H2_Geneva  https://pbs.twimg.com/profile_images/778233965...
# 1      AnnaRHaskins  https://pbs.twimg.com/profile_images/941757829...
# 2        faziarizvi  https://pbs.twimg.com/profile_images/537347315...
# 3         Gbolarin_  https://pbs.twimg.com/profile_images/105372443...
# 4        Rwanda_Edu  https://pbs.twimg.com/profile_images/919159851...
# 5             tjfas  https://pbs.twimg.com/profile_images/990293406...
# 6         chris_m_h  https://pbs.twimg.com/profile_images/956196343...
# 7       RoyalKenyah  https://pbs.twimg.com/profile_images/106073457...
# 8          kunleMyk  https://pbs.twimg.com/profile_images/103889242...
# 9   nicktubechannel  https://pbs.twimg.com/profile_images/105331498...
# 10       TheMacAnon  https://pbs.twimg.com/profile_images/106292210...
# 11          Asamoh_  https://pbs.twimg.com/profile_images/106637654...
# 12   ForeverEritrea  https://pbs.twimg.com/profile_images/102607938...
# 13    Qwame_Dankwah  https://pbs.twimg.com/profile_images/104632593...
# 14      Ody_johnson  https://pbs.twimg.com/profile_images/972810031...
# 15      WaleMicaiah  https://pbs.twimg.com/profile_images/481291469...
# 16      SaleemAmusa  https://pbs.twimg.com/profile_images/105998304...
# 17  UgochiJaneTrump  https://pbs.twimg.com/profile_images/106513858...
# 18            woye1  https://pbs.twimg.com/profile_images/100845526...
# 19       daylalalal  https://pbs.twimg.com/profile_images/103975772...
# 20  Change_Maldives  https://pbs.twimg.com/profile_images/960728525...
# 21   NigerDeltaRpts  https://pbs.twimg.com/profile_images/103554458...
# 22       GCICUganda  https://pbs.twimg.com/profile_images/876008041...
# 23    jackielidubwi  https://pbs.twimg.com/profile_images/931518185...
# 24        MaxCRoser  https://pbs.twimg.com/profile_images/991373737...
# 25          SDGsNGA  https://pbs.twimg.com/profile_images/667322075...
# 26         iameneji  https://pbs.twimg.com/profile_images/105442348...
# 27       Kempez2017  https://pbs.twimg.com/profile_images/105505366...
# 28       Miryam1968  https://pbs.twimg.com/profile_images/100615211...
# 29      BethuTongai  https://pbs.twimg.com/profile_images/978914915...
# 30      LeviKabwato  https://pbs.twimg.com/profile_images/106114652...
# 31       msmarbella  https://pbs.twimg.com/profile_images/810267964...
#
#                    tw_time                                            tw_text  \
# 0    6:08 AM - 28 Nov 2018  Global health disruptors: Millennium developme...
# 1    1:35 AM - 28 Nov 2018  In class today I referenced the Millennium Dev...
# 2    5:04 PM - 26 Nov 2018  "One of the United Nations’ Millennium Develop...
# 3    7:35 PM - 24 Nov 2018  3\nThe SDGs are an offshoot of the now outdate...
# 4    7:32 PM - 23 Nov 2018  .@MinisterRw_Edu :One of the key strategic pri...
# 5    5:30 PM - 22 Nov 2018  Politics apart my people, how is it possible u...
# 6    4:18 PM - 22 Nov 2018  The Strategic Development Goals are audacious,...
# 7    7:29 AM - 22 Nov 2018  The 17 Sustainable development goals build on ...
# 8    6:32 AM - 22 Nov 2018  How well can you pronounce "Millennium Develop...
# 9    3:27 PM - 21 Nov 2018  These 17 Goals build on the successes of the M...
# 10   9:14 AM - 21 Nov 2018  Titled (Transforming) our world: the 2030 Agen...
# 11   5:44 AM - 21 Nov 2018  The Millennium Development Goals measure progr...
# 12   2:52 AM - 21 Nov 2018  "SHEER WILLPOWER!\nWe were the ONLY Sub-Sahara...
# 13  10:07 AM - 20 Nov 2018  In 2000, the Millennium Development Goals outl...
# 14   7:56 PM - 19 Nov 2018  Hello Mr Abubakar ,i know you are tired of my ...
# 15   3:25 PM - 19 Nov 2018  Millennium Development Goals ended in 2015\n\n...
# 16   2:35 PM - 19 Nov 2018  We need to enforce the charge right acts.. We ...
# 17   2:16 PM - 19 Nov 2018  We are warning you, #TheAtikuPlan will take us...
# 18  11:13 AM - 19 Nov 2018  What is Millennium Development Goals and what ...
# 19  10:21 AM - 19 Nov 2018  To combat this global sanitation crisis we nee...
# 20    7:04 AM - 9 Nov 2018  That must be an injustice to say MAG’s Nationa...
# 21    2:10 PM - 8 Nov 2018  “It is aimed at transforming the amnesty benef...
# 22   11:08 AM - 7 Nov 2018  #SDGs were adopted in 2015 by the United Natio...
# 23    8:35 AM - 7 Nov 2018  LEGAL FRAMEWORK.\n- The UNCPRD\n- Constitution...
# 24    1:21 PM - 6 Nov 2018  Did the world actually achieve the Millennium ...
# 25   10:56 AM - 6 Nov 2018  Sustainable Development Goals:\n\nStarted 2015...
# 26    5:07 AM - 6 Nov 2018  Good morning beautiful people. The rest of you...
# 27    4:41 AM - 6 Nov 2018  Let me even help you with the details for free...
# 28    9:28 PM - 2 Nov 2018  The amendments are related to the fulfilment o...
# 29    3:59 PM - 2 Nov 2018  Do you even know about the international law b...
# 30    3:58 AM - 2 Nov 2018  Intriguing that consequences of neo-liberalism...
# 31    6:15 PM - 1 Nov 2018  2. have been working on ways to implement univ...
#
#     tw_replies  tw_retweets  tw_favorites
# 0            1            2             6
# 1            3            2            92
# 2            1            0             0
# 3            1            2             0
# 4            2            8             7
# 5            1            0             0
# 6            1            4             8
# 7            1            9             9
# 8           14           28             5
# 9            1            1             3
# 10           1            0             0
# 11           1            1             2
# 12           1            7            13
# 13           1            4             5
# 14           1            7             6
# 15           1            7             8
# 16           1            0             0
# 17           1            3             4
# 18           5           42            56
# 19           1            1             2
# 20           1            0             0
# 21           1            0             0
# 22           1            2             1
# 23           1            2             3
# 24           2           28            36
# 25           3           11            12
# 26           2            6            35
# 27           1            0             0
# 28           1            0             1
# 29           1            0             0
# 30           1            0             0
# 31           1            0             0

# %%
#Filter out all those tweets that do not have any replies and show the rest
df.query('tw_replies > 0').reset_index(drop=True)
# Out:
#          tweeter_id                                         avatar_url  \
# 0       G2H2_Geneva  https://pbs.twimg.com/profile_images/778233965...
# 1      AnnaRHaskins  https://pbs.twimg.com/profile_images/941757829...
# 2        faziarizvi  https://pbs.twimg.com/profile_images/537347315...
# 3         Gbolarin_  https://pbs.twimg.com/profile_images/105372443...
# 4        Rwanda_Edu  https://pbs.twimg.com/profile_images/919159851...
# 5             tjfas  https://pbs.twimg.com/profile_images/990293406...
# 6         chris_m_h  https://pbs.twimg.com/profile_images/956196343...
# 7       RoyalKenyah  https://pbs.twimg.com/profile_images/106073457...
# 8          kunleMyk  https://pbs.twimg.com/profile_images/103889242...
# 9   nicktubechannel  https://pbs.twimg.com/profile_images/105331498...
# 10       TheMacAnon  https://pbs.twimg.com/profile_images/106292210...
# 11          Asamoh_  https://pbs.twimg.com/profile_images/106637654...
# 12   ForeverEritrea  https://pbs.twimg.com/profile_images/102607938...
# 13    Qwame_Dankwah  https://pbs.twimg.com/profile_images/104632593...
# 14      Ody_johnson  https://pbs.twimg.com/profile_images/972810031...
# 15      WaleMicaiah  https://pbs.twimg.com/profile_images/481291469...
# 16      SaleemAmusa  https://pbs.twimg.com/profile_images/105998304...
# 17  UgochiJaneTrump  https://pbs.twimg.com/profile_images/106513858...
# 18            woye1  https://pbs.twimg.com/profile_images/100845526...
# 19       daylalalal  https://pbs.twimg.com/profile_images/103975772...
# 20  Change_Maldives  https://pbs.twimg.com/profile_images/960728525...
# 21   NigerDeltaRpts  https://pbs.twimg.com/profile_images/103554458...
# 22       GCICUganda  https://pbs.twimg.com/profile_images/876008041...
# 23    jackielidubwi  https://pbs.twimg.com/profile_images/931518185...
# 24        MaxCRoser  https://pbs.twimg.com/profile_images/991373737...
# 25          SDGsNGA  https://pbs.twimg.com/profile_images/667322075...
# 26         iameneji  https://pbs.twimg.com/profile_images/105442348...
# 27       Kempez2017  https://pbs.twimg.com/profile_images/105505366...
# 28       Miryam1968  https://pbs.twimg.com/profile_images/100615211...
# 29      BethuTongai  https://pbs.twimg.com/profile_images/978914915...
# 30      LeviKabwato  https://pbs.twimg.com/profile_images/106114652...
# 31       msmarbella  https://pbs.twimg.com/profile_images/810267964...
#
#                    tw_time                                            tw_text  \
# 0    6:08 AM - 28 Nov 2018  Global health disruptors: Millennium developme...
# 1    1:35 AM - 28 Nov 2018  In class today I referenced the Millennium Dev...
# 2    5:04 PM - 26 Nov 2018  "One of the United Nations’ Millennium Develop...
# 3    7:35 PM - 24 Nov 2018  3\nThe SDGs are an offshoot of the now outdate...
# 4    7:32 PM - 23 Nov 2018  .@MinisterRw_Edu :One of the key strategic pri...
# 5    5:30 PM - 22 Nov 2018  Politics apart my people, how is it possible u...
# 6    4:18 PM - 22 Nov 2018  The Strategic Development Goals are audacious,...
# 7    7:29 AM - 22 Nov 2018  The 17 Sustainable development goals build on ...
# 8    6:32 AM - 22 Nov 2018  How well can you pronounce "Millennium Develop...
# 9    3:27 PM - 21 Nov 2018  These 17 Goals build on the successes of the M...
# 10   9:14 AM - 21 Nov 2018  Titled (Transforming) our world: the 2030 Agen...
# 11   5:44 AM - 21 Nov 2018  The Millennium Development Goals measure progr...
# 12   2:52 AM - 21 Nov 2018  "SHEER WILLPOWER!\nWe were the ONLY Sub-Sahara...
# 13  10:07 AM - 20 Nov 2018  In 2000, the Millennium Development Goals outl...
# 14   7:56 PM - 19 Nov 2018  Hello Mr Abubakar ,i know you are tired of my ...
# 15   3:25 PM - 19 Nov 2018  Millennium Development Goals ended in 2015\n\n...
# 16   2:35 PM - 19 Nov 2018  We need to enforce the charge right acts.. We ...
# 17   2:16 PM - 19 Nov 2018  We are warning you, #TheAtikuPlan will take us...
# 18  11:13 AM - 19 Nov 2018  What is Millennium Development Goals and what ...
# 19  10:21 AM - 19 Nov 2018  To combat this global sanitation crisis we nee...
# 20    7:04 AM - 9 Nov 2018  That must be an injustice to say MAG’s Nationa...
# 21    2:10 PM - 8 Nov 2018  “It is aimed at transforming the amnesty benef...
# 22   11:08 AM - 7 Nov 2018  #SDGs were adopted in 2015 by the United Natio...
# 23    8:35 AM - 7 Nov 2018  LEGAL FRAMEWORK.\n- The UNCPRD\n- Constitution...
# 24    1:21 PM - 6 Nov 2018  Did the world actually achieve the Millennium ...
# 25   10:56 AM - 6 Nov 2018  Sustainable Development Goals:\n\nStarted 2015...
# 26    5:07 AM - 6 Nov 2018  Good morning beautiful people. The rest of you...
# 27    4:41 AM - 6 Nov 2018  Let me even help you with the details for free...
# 28    9:28 PM - 2 Nov 2018  The amendments are related to the fulfilment o...
# 29    3:59 PM - 2 Nov 2018  Do you even know about the international law b...
# 30    3:58 AM - 2 Nov 2018  Intriguing that consequences of neo-liberalism...
# 31    6:15 PM - 1 Nov 2018  2. have been working on ways to implement univ...
#
#     tw_replies  tw_retweets  tw_favorites
# 0            1            2             6
# 1            3            2            92
# 2            1            0             0
# 3            1            2             0
# 4            2            8             7
# 5            1            0             0
# 6            1            4             8
# 7            1            9             9
# 8           14           28             5
# 9            1            1             3
# 10           1            0             0
# 11           1            1             2
# 12           1            7            13
# 13           1            4             5
# 14           1            7             6
# 15           1            7             8
# 16           1            0             0
# 17           1            3             4
# 18           5           42            56
# 19           1            1             2
# 20           1            0             0
# 21           1            0             0
# 22           1            2             1
# 23           1            2             3
# 24           2           28            36
# 25           3           11            12
# 26           2            6            35
# 27           1            0             0
# 28           1            0             1
# 29           1            0             0
# 30           1            0             0
# 31           1            0             0

# %%
#You can also use conditional statements that have boolean operators such as when filtering those that have retweets or favorites more than or equal to 10
df.query('tw_retweets >=10 or tw_favorites>=10').reset_index(drop=True)
# Out:
#         tweeter_id                                         avatar_url  \
# 0     AnnaRHaskins  https://pbs.twimg.com/profile_images/941757829...
# 1         kunleMyk  https://pbs.twimg.com/profile_images/103889242...
# 2      MadiSharma1  https://pbs.twimg.com/profile_images/610387093...
# 3   ForeverEritrea  https://pbs.twimg.com/profile_images/102607938...
# 4   Underground_RT  https://pbs.twimg.com/profile_images/104788960...
# 5         adex0057  https://pbs.twimg.com/profile_images/105539528...
# 6           MSTCDC  https://pbs.twimg.com/profile_images/953607386...
# 7            woye1  https://pbs.twimg.com/profile_images/100845526...
# 8        ayo_david  https://pbs.twimg.com/profile_images/100249482...
# 9        MaxCRoser  https://pbs.twimg.com/profile_images/991373737...
# 10         SDGsNGA  https://pbs.twimg.com/profile_images/667322075...
# 11        iameneji  https://pbs.twimg.com/profile_images/105442348...
# 12    amutunga2011  https://pbs.twimg.com/profile_images/105972869...
# 13       atabinore  https://pbs.twimg.com/profile_images/103279388...
#
#                    tw_time                                            tw_text  \
# 0    1:35 AM - 28 Nov 2018  In class today I referenced the Millennium Dev...
# 1    6:32 AM - 22 Nov 2018  How well can you pronounce "Millennium Develop...
# 2   11:40 AM - 21 Nov 2018  BANGLADESH - EXCEEDING EXPECTATIONS - Happy to...
# 3    2:52 AM - 21 Nov 2018  "SHEER WILLPOWER!\nWe were the ONLY Sub-Sahara...
# 4    1:05 PM - 20 Nov 2018  "SHEER WILLPOWER! We were the ONLY Sub-Saharan...
# 5    9:21 AM - 20 Nov 2018  Atiku campaigns told Nigeria is developmental ...
# 6    5:25 AM - 20 Nov 2018  "There is a huge different between sustainable...
# 7   11:13 AM - 19 Nov 2018  What is Millennium Development Goals and what ...
# 8   10:44 AM - 19 Nov 2018  Misleading. It's talking about Human developme...
# 9     1:21 PM - 6 Nov 2018  Did the world actually achieve the Millennium ...
# 10   10:56 AM - 6 Nov 2018  Sustainable Development Goals:\n\nStarted 2015...
# 11    5:07 AM - 6 Nov 2018  Good morning beautiful people. The rest of you...
# 12   11:27 AM - 3 Nov 2018  The millennium development goals era did not m...
# 13   12:07 PM - 1 Nov 2018  A1. SDGs are goals formulated to build on the ...
#
#     tw_replies  tw_retweets  tw_favorites
# 0            3            2            92
# 1           14           28             5
# 2            0            2            13
# 3            1            7            13
# 4            0           34            54
# 5            0           10            17
# 6            0           11            13
# 7            5           42            56
# 8            0            3            10
# 9            2           28            36
# 10           3           11            12
# 11           2            6            35
# 12           0            4            10
# 13           0            9            18

# %% [markdown]
# ### 13) Writing DataFrames to CSV files
# #### To write dataframes to CSV files, you can always use the to_csv() function as shown below:

# %%
#Let's write the contents of df to 'output.csv'
df.to_csv('output.csv')

#And now let's read it (but let's drop the index) and confirm that all is in order
pd.read_csv('output.csv').head()
# Out:
#    Unnamed: 0    tweeter_id  \
# 0           0   GSTICseries
# 1           1      11ionArt
# 2           2   G2H2_Geneva
# 3           3  AnnaRHaskins
# 4           4     PensiveTM
#
#                                           avatar_url                 tw_time  \
# 0  https://pbs.twimg.com/profile_images/875623570...   1:25 PM - 28 Nov 2018
# 1  https://pbs.twimg.com/profile_images/106785384...  11:20 AM - 28 Nov 2018
# 2  https://pbs.twimg.com/profile_images/778233965...   6:08 AM - 28 Nov 2018
# 3  https://pbs.twimg.com/profile_images/941757829...   1:35 AM - 28 Nov 2018
# 4  https://pbs.twimg.com/profile_images/104786562...   6:08 PM - 27 Nov 2018
#
#                                              tw_text  tw_replies  tw_retweets  \
# 0  All fueled up? Afternoon session (Waste)#Water...           0            1
# 1  DID YOU KNOW? 5 Ongoing Trends that Will Resha...           0            1
# 2  Global health disruptors: Millennium developme...           1            2
# 3  In class today I referenced the Millennium Dev...           3            2
# 4  The true extent of global poverty and hunger: ...           0            1
#
#    tw_favorites
# 0             2
# 1             0
# 2             6
# 3            92
# 4             1

# %% [markdown]
# ### Great!
# #### We have now learned the most important pandas functions that allow you to do some basic data analysis.
# #### To learn more, check the documentation [here](https://pandas.pydata.org/pandas-docs/stable/)

# %% [markdown]
# # Exercise:
#
# ### **Task:**
#
# Write a script that reads the CSV you created last workshop to create 2 CSV files as per the following:
# - CSV file 1 should contain the list of tweets sorted by number of retweets and then by number of favorites (top retweets first).
# - CSV file 2 should contain the list of tweeters (users) and number of tweets they each published, the number of total retweets and favorites they each got. The data in the file should be sorted by the total number of favorites, then retweets, then replies (highest first).
#
# Upload the script and the two CSV files to the desgintated inlämning link on Studiewebben.
